# %% [markdown]
# <a href="https://colab.research.google.com/github/Rishabh07-cell/RishabhRaj-leetcodeSolutions-/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install flask flask-cors python-dotenv pyngrok requests

# %%
# %%writefile .env
# OPENAI_API_KEY=AIzaSyC4LMHT42HN7Jx74JsavWGACK4sb2orG58
# Out:
# Overwriting .env

# %%
# %%writefile app.py
from flask import Flask, request, jsonify
from flask_cors import CORS
import os
import requests

app = Flask(__name__)
CORS(app)

OPENAI_KEY = os.getenv("OPENAI_API_KEY")

@app.route("/api/generate", methods=["POST"])
def generate_prompt():
    data = request.json
    role = data.get("role", "Developer")
    task = data.get("task", "Describe the task")
    style = data.get("style", "detailed")

    prompt = f"You are a {role}. {task}. Write in {style} style."

    return jsonify({"prompt": prompt})

if __name__ == "__main__":
    app.run()
# Out:
# Writing app.py

# %%
from pyngrok import ngrok
ngrok.set_auth_token("36QHDQ3FOZzVp62c2A3CvpiNTH1_7k2SwsSzMcYoPrZ1T51TN")

# %%
public_url = ngrok.connect(5000)
print(public_url)
# !python app.py
# Out:
# NgrokTunnel: "https://heartsick-sanctifiably-elma.ngrok-free.dev" -> "http://localhost:5000"
#  * Serving Flask app 'app'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [05/Dec/2025 11:04:52] "GET / HTTP/1.1" 404 -
# 127.0.0.1 - - [05/Dec/2025 11:04:52] "GET /favicon.ico HTTP/1.1" 404 -
